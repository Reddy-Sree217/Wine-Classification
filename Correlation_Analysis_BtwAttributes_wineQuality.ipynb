# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
Dataframe = pd.read_csv(R'C:\Users\sreen\Desktop\BTP\Maize_Correlation.csv')

# %%
Dataframe.head()
# Out:
#       N     P     K  temperature   humidity        ph    rainfall  label
# 0  71.0  54.0  16.0    22.613600  63.690706  5.749914   87.759539      1
# 1  61.0  44.0  17.0    26.100184  71.574769  6.931757  102.266244      1
# 2  80.0  43.0  16.0    23.558821  71.593514  6.657965   66.719955      1
# 3  73.0  58.0  21.0    19.972160  57.682729  6.596061   60.651715      1
# 4  61.0  38.0  20.0    18.478913  62.695039  5.970458   65.438354      1

# %%
Dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            986 non-null    float64
#  1   P            986 non-null    float64
#  2   K            986 non-null    float64
#  3   temperature  986 non-null    float64
#  4   humidity     986 non-null    float64
#  5   ph           986 non-null    float64
#  6   rainfall     986 non-null    float64
#  7   label        986 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 61.8 KB

# %%
Dataframe.describe()
# Out:
#                 N           P           K  temperature    humidity  \
# count  986.000000  986.000000  986.000000   986.000000  986.000000
# mean    84.126244   51.552386   24.689472    29.246947   71.737511
# std      5.492891    3.198537    3.199971     7.918155    7.550186
# min     60.000000   35.000000   15.000000    18.041855   55.282204
# 25%     81.752889   50.451551   22.708737    22.171336   65.625096
# 50%     84.099964   51.588515   24.493021    22.446979   66.155070
# 75%     87.040963   53.050825   26.668306    37.875545   78.627202
# max    100.000000   60.000000   31.475962    45.321000   87.602765
#
#                ph    rainfall       label
# count  986.000000  986.000000  986.000000
# mean     4.016266   75.975106    0.556795
# std      2.916405   15.265968    0.497016
# min     -3.530617   36.500000    0.000000
# 25%      1.627447   64.299571    0.000000
# 50%      6.245647   84.950546    1.000000
# 75%      6.430585   87.310164    1.000000
# max      6.995844  109.751538    1.000000

# %%
Dataframe.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
sb.pairplot(Dataframe)
plt.show()

# %%
Dataframe.hist(bins=20,figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=[18,7])
# plot correlation
sb.heatmap(Dataframe.corr(),annot=True)
plt.show()
